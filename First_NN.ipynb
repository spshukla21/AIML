# %% [markdown]
# <a href="https://colab.research.google.com/github/spshukla21/AIML/blob/master/First_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
tensorflow.__version__
# Out:
# '2.2.0'

# %%
# Initialize the random number generator
import random
random.seed(0)

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(trainX, trainY), (testX,testY) = fashion_mnist.load_data()

# %%
print('Train X Shape = ',trainX.shape)
print('Train Y Shape = ',trainY.shape)
print('Test X Shape = ',testX.shape)
print('Test Y Shape = ',testY.shape)
# Out:
# Train X Shape =  (60000, 28, 28)
# Train Y Shape =  (60000,)
# Test X Shape =  (10000, 28, 28)
# Test Y Shape =  (10000,)

# %%
testY.view()
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
trainY = tf.keras.utils.to_categorical(trainY,num_classes=10)
testY = tf.keras.utils.to_categorical(testY,num_classes=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for i in range(20):
    image = trainX[i]
    plt.figure(i)
    plt.imshow(image)

# %%
#Initialize sequenial model
model = tf.keras.models.Sequential()

# %%
#Reshape data from 2D to 1D ->28*28 to 784
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

# %%
#Add Dense layer which provides 10 outputs after applying softmax
model.add(tf.keras.layers.Dense(10,activation = 'softmax'))

# %%
#compile the model
model.compile(optimizer='sgd', loss='categorical_crossentropy',  metrics = ['accuracy'])

# %%
model.fit(trainX,trainY,epochs=10,validation_data=(testX,testY),batch_size=trainX.shape[0])
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 252ms/step - loss: 2.3192 - accuracy: 0.0677 - val_loss: 2.3015 - val_accuracy: 0.0906
# Epoch 2/10
# 1/1 [==============================] - 0s 99ms/step - loss: 2.3040 - accuracy: 0.0900 - val_loss: 2.2963 - val_accuracy: 0.0953
# Epoch 3/10
# 1/1 [==============================] - 0s 67ms/step - loss: 2.2987 - accuracy: 0.0948 - val_loss: 2.2920 - val_accuracy: 0.0984
# Epoch 4/10
# 1/1 [==============================] - 0s 75ms/step - loss: 2.2947 - accuracy: 0.0972 - val_loss: 2.2886 - val_accuracy: 0.0985
# Epoch 5/10
# 1/1 [==============================] - 0s 68ms/step - loss: 2.2910 - accuracy: 0.0988 - val_loss: 2.2849 - val_accuracy: 0.1004
# Epoch 6/10
# 1/1 [==============================] - 0s 67ms/step - loss: 2.2879 - accuracy: 0.1011 - val_loss: 2.2825 - val_accuracy: 0.1007
# Epoch 7/10
# ...
